# %%
# %matplotlib inline
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
matplotlib.style.use('ggplot')

# %%
df = pd.read_csv('bumi.csv')

# %% [markdown]
# df2 = pd.read_csv('/home/partu/Downloads/FB Scrap/843907732327130_facebook_statuses.csv')

# %%
df.head()
# Out:
#                            status_id  \
# 0  1406946659595217_1861120787511133
# 1  1406946659595217_1861372734152605
# 2  1406946659595217_1861335054156373
# 3  1406946659595217_1861263704163508
# 4  1406946659595217_1536079946681887
#
#                                       status_message      status_author  \
# 0                                                NaN      Kyaw Zay Latt
# 1                  မေန႔က စပပ်ံ ဒီေန႔က ေဂြးခ်ံဳသိုင္း          John Cool
# 2  ေတြ႔တဲ့ပုံေပၚစာေရးလိုက္ပါတယ္ အစ္ကိုတို႔ေရ မွီမ...       Myat Thurein
# 3  ဒီးယားဒလုိဘာလုိလုိညာလုိုိလုိ\nအမူ​း​ေျပရင္​ဘာမ...      Yan Naing Lin
# 4  ကမၻာကို ရင္ေဘာင္တန္နိုင္ေအာင္လို႔ ကမၻာကေလစားတဲ...  Yin Aung Yin Aung
#
#                               link_name status_type  \
# 0                                   NaN       photo
# 1                                   NaN       photo
# 2                                   NaN       photo
# 3                                   NaN       photo
# ...

# %%
df.status_published = pd.to_datetime(df.status_published)

# %%
df.plot(x=['status_published'], y = ['num_shares','num_comments','num_likes'],subplots=True,sort_columns=False, figsize=(24,16))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fc107bcd550>,
# ...
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fc107266898>], dtype=object)

# %%
df.plot(x=['status_published'], y = ['num_loves','num_wows','num_hahas','num_sads','num_angrys'],subplots=True,sort_columns=False, figsize=(24,16))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fc107871e10>,
# ...
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fc106f3f5f8>], dtype=object)

# %%
plt.savefig('reaction1.pdf')

# %%
df.describe()
# Out:
#        num_reactions  num_comments    num_shares     num_likes    num_loves  \
# count    1598.000000   1598.000000   1598.000000   1598.000000  1598.000000
# mean     4673.854819    205.399249    603.565707   4521.308511    52.453066
# std      4907.721816    479.079908   1410.273286   4736.346131   104.648148
# min       135.000000      0.000000      0.000000    131.000000     0.000000
# 25%      1959.750000     18.000000    107.000000   1902.250000     5.000000
# 50%      3235.000000     71.500000    205.000000   3134.500000    14.000000
# 75%      5559.750000    219.000000    500.750000   5439.250000    71.000000
# max     44149.000000   9618.000000  27144.000000  43930.000000  1631.000000
#
#           num_wows    num_hahas     num_sads   num_angrys  num_special
# count  1598.000000  1598.000000  1598.000000  1598.000000  1598.000000
# mean     21.473717    43.386108    20.808511    13.840426     0.584481
# std      48.034912   166.296253   109.971868    71.548506     6.419195
# ...

# %%
df.plot(x='status_published', y=['num_shares','num_comments'], figsize=(24,16))

# %%
plt.savefig('reaction2.pdf')

# %%
df.sort_values('num_reactions', ascending=False).head(10)
# Out:
#                               status_id  \
# 2935  1406946659595217_1714169112206302
# 114   1406946659595217_1562385947384620
# 785   1406946659595217_1853294804960398
# 3851  1406946659595217_1838215053135040
# 3217  1406946659595217_1548203758802839
# 4392  1406946659595217_1653772004912680
# 2969  1406946659595217_1683236961966184
# 1874  1406946659595217_1674302576192956
# 4133  1406946659595217_1652579971698550
# 499   1406946659595217_1853725714917307
#
#                                          status_message  \
# 2935                                               😔😔😔😔
# 114   က်ေနာ္ ခ်ီးပါလိုက္သည္\n\nLiberalsim- လူသားတိုင...
# 785                                  ၿပီးပါပီ အကို​ေရ..
# 3851  ဖြဘုတ္​​ေဒရဲ ့အျပင္​ဘက္​\nဒဂံုတက္​ကသိုလ္​ႀကီးရ...
# ရင္ျငိ္မ္းပြင့္ကို မွတ္မိေသးတယ္ဆုိ\nခင္ဗ်ား f...
# 4392                                          Not Ts :(
# 2969         Meanwhile in Burma...\nEdited again 😂😂😂🙏🙏🙏
# 1874                                               hrrr
# ...

# %%
df.status_link.loc[785:'status_link']
# Out:
# 785     https://www.facebook.com/140293736503927/video...
# 786     https://www.facebook.com/1374300052893950/vide...
# 787     https://www.facebook.com/photo.php?fbid=144497...
# 788     https://www.facebook.com/photo.php?fbid=424467...
# 789     https://www.facebook.com/photo.php?fbid=970642...
# 790     https://www.facebook.com/photo.php?fbid=474919...
# 791     https://www.facebook.com/photo.php?fbid=185439...
# 792     https://www.facebook.com/photo.php?fbid=101550...
# 793     https://www.facebook.com/photo.php?fbid=145329...
# 794     https://www.facebook.com/photo.php?fbid=192536...
# 795     https://www.facebook.com/photo.php?fbid=122922...
# 796     https://www.facebook.com/photo.php?fbid=475643...
# 797     https://www.facebook.com/photo.php?fbid=540999...
# 798     https://www.facebook.com/photo.php?fbid=491745...
# 799     https://www.facebook.com/photo.php?fbid=505275...
# 800     https://www.facebook.com/photo.php?fbid=102106...
# ...

# %%
df.plot(x='status_published', y=['num_loves','num_wows','num_hahas','num_sads','num_angrys'], figsize=(24,16))

# %%
df.plot(x='status_published', y=['num_hahas'], figsize=(24,16))

# %%
plt.savefig('reaction3.pdf')

# %%
df[['num_loves', 'num_wows','num_hahas','num_sads','num_angrys']].mean().plot(kind='bar')

# %%
df[['num_loves', 'num_wows','num_hahas','num_sads','num_angrys']].sum().plot(title ='lu',autopct='%.2f',kind='pie', figsize=(6,6))

# %% [markdown]
# Below is Comparing Two Dataframes

# %% [markdown]
# df['Key'] = 'trail1'
# df2['Key'] = 'trail2'

# %% [markdown]
# DF = pd.concat([df,df2],keys=['trail1','trail2'])

# %% [markdown]
# DF.status_published = pd.to_datetime(DF.status_published)

# %% [markdown]
# DFGroup = DF.groupby(['status_published','Key'])

# %% [markdown]
# DFGroup.head()

# %% [markdown]
# DFGroup.sum().plot(kind='line')
