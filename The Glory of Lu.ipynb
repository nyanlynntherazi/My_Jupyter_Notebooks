# %%
# %matplotlib inline
import pandas as pd

# %%
df = pd.read_csv('../partu/Downloads/FB Scrap/843907732327130_facebook_statuses.csv')

# %%
df.head()
# Out:
#                           status_id  \
# 0  843907732327130_1614555258595703
# 1  843907732327130_1611800675537828
# 2  843907732327130_1609158605802035
# 3  843907732327130_1609260939125135
# 4  843907732327130_1609031775814718
#
#                                       status_message  \
# 0  ဒီတစ္ပတ္ Business Friday မွာ  Founder ေတြနဲ႕ F...
# 1  လာမယ့္ စက္တင္ဘာ ၂၀ ရက္ေန႔ (ဗုဒၶဟူးေန႔႔) ညေန ၆န...
# 2  ဒီဇိုင္းတစ္ခုကိုဖန္တီးတဲ့အခါ မွာ ပါဝင္တဲ့ အ႐ုပ...
# 3  ဖန္တီးရာမွာ က်င္းပမယ့္ Makermeetup အတြက္ ျမန္မ...
# 4  မိတ္ေဆြတုိရဲ႕ စီးပြားေရးနဲ႕ ထုတ္ကုန္ေတြ ပိုမို...
#
#                        link_name status_type  \
# 0  Photos from Phandeeyar's post       photo
# 1                Timeline Photos       photo
# 2                            NaN       photo
# 3                Timeline Photos       photo
# 4  Photos from Phandeeyar's post       photo
#
#                                          status_link  \
# 0  https://www.facebook.com/phandeeyar/photos/a.8...
# ...

# %%
df.plot()

# %%
df.describe()
# Out:
#        num_reactions  num_comments  num_shares     num_likes   num_loves  \
# count     933.000000    933.000000  933.000000    933.000000  933.000000
# mean      206.609861      3.891747   16.308682    202.084673    2.943194
# std       634.475966     15.341816   44.976545    613.455804   22.801955
# min         1.000000      0.000000    0.000000      1.000000    0.000000
# 25%        25.000000      0.000000    2.000000     25.000000    0.000000
# 50%        49.000000      1.000000    6.000000     49.000000    0.000000
# 75%       107.000000      4.000000   17.000000    105.000000    1.000000
# max     10914.000000    404.000000  984.000000  10198.000000  496.000000
#
#          num_wows   num_hahas    num_sads  num_angrys
# count  933.000000  933.000000  933.000000  933.000000
# mean     1.346195    0.114684    0.084673    0.016077
# std      8.652146    0.532958    1.971446    0.141871
# min      0.000000    0.000000    0.000000    0.000000
# ...
